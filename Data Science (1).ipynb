# %%
import pandas as pd
import numpy as np

#create pandas DataFrame with raw data
df = pd.DataFrame({'gender': np.repeat(np.array(['Male', 'Female']), 150),
                   'sport': np.repeat(np.array(['Baseball', 'Basketball', 'Football',
                                                'Soccer', 'Baseball', 'Basketball',
                                                'Football', 'Soccer']), 
                                    (34, 40, 58, 18, 34, 52, 20, 44))})
df2=pd.DataFrame(data=df)
df2
# Out:
#      gender     sport
# 0      Male  Baseball
# 1      Male  Baseball
# 2      Male  Baseball
# 3      Male  Baseball
# 4      Male  Baseball
# ..      ...       ...
# 295  Female    Soccer
# 296  Female    Soccer
# 297  Female    Soccer
# 298  Female    Soccer
# 299  Female    Soccer
#
# [300 rows x 2 columns]

# %%
df2.value_counts()
# Out:
# gender  sport
# Male    Football      58
# Female  Basketball    52
#         Soccer        44
# Male    Basketball    40
# Female  Baseball      34
# Male    Baseball      34
# Female  Football      20
# Male    Soccer        18
# dtype: int64

# %%
survey_data = pd.crosstab(index=df['gender'], columns=df['sport'], margins=True)

# %%
survey_data
# Out:
# sport   Baseball  Basketball  Football  Soccer  All
# gender
# Female        34          52        20      44  150
# Male          34          40        58      18  150
# All           68          92        78      62  300

# %%
k=survey_data.loc['Female'][:4]

# %%
mean=survey_data.iloc[0,4]/k.value_counts().sum()
mean
# Out:
# 37.5

# %%
from scipy import stats as s 
import statistics as ss

# %%
list1=list(k)
median=ss.median(list1)
print(median)
# Out:
# 39.0

# %%
ss.variance(list1)
# Out:
# 190.33333333333334

# %%
ss.stdev(list1)
# Out:
# 13.796134724383252

# %%
#a=[1,2,3,4,5,6]

# %%
print(10+6)
# Out:
# 16

# %%
# Input:
# leetcode 
# leet code
# Output: 
# True
# asa="leetcode"
# b="leet code"
# c=b.split()
# print(c)

# %%
ans=[]
def per(a,b):
    if len(a)==0:
        ans.append(b)
        return
    for i in range(len(a)):
        temp=a[i]
        left=a[0:i]
        right=a[i+1:]
        x=left+right
        per(x,b+temp)
s="abc"
r=' '
per(s,r)
p=[]
for j in ans:
    p.append(j)
print(p)
# Out:
# [' abc', ' acb', ' bac', ' bca', ' cab', ' cba']

# %%
v=-5
f=1
if v<0:
    print("-ve")
else:
    for i in range(f,v+1):
        f=f*i
    print(f)
# Out:
# -ve

# %%
n=10
x=0
y=1
z=0
while(z<=n):
    print(z)
    z=x+y
    x=y
    y=z
# Out:
# 0
# 1
# 2
# 3
# 5
# 8

# %%
a1=[-5,4,6,-3,4,-1]
for i in range(len(a1)):
    for j in range(i,len(a1)):
        for k in range(i,j+1):
            print(a1[k],end=' ')
        print()
# Out:
# -5
# -5 4
# -5 4 6
# -5 4 6 -3
# -5 4 6 -3 4
# -5 4 6 -3 4 -1
# 4
# 4 6
# 4 6 -3
# 4 6 -3 4
# 4 6 -3 4 -1
# 6
# 6 -3
# 6 -3 4
# 6 -3 4 -1
# -3
# -3 4
# -3 4 -1
# 4
# 4 -1
# -1

# %%
a1=[-5,4,6,-3,4,-1]
c=0
maxi=a1[0]
st=0
en=0
poi=0
for i in range(len(a1)):
    c=a1[i]+c
    if maxi<c:
        maxi=c
        st=poi
        en=i
    if c<0:
        c=0
        poi=poi+1
print(maxi)
print(st,en)
# Out:
# 11
# 1 4

# %% [markdown]
# # Assignment 1

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('fifa.csv')

# %%
df.head()
# Out:
#        ID               Name   Age Nationality  Overall  Potential  \
# 0  158023           L. Messi  31.0   Argentina     94.0       94.0
# 1   20801  Cristiano Ronaldo  33.0    Portugal     94.0       94.0
# 2  190871          Neymar Jr  26.0      Brazil     92.0       93.0
# 3  193080             De Gea  27.0       Spain     91.0       93.0
# 4  192985       K. De Bruyne  27.0     Belgium     91.0       92.0
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF  2004.0
# 1                       5.0          5.0       ST  2018.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18204 non-null  float64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18195 non-null  float64
#  5   Potential                 18206 non-null  float64
#  6   Club                      17966 non-null  object
#  7   Value                     17947 non-null  float64
#  8   Wage                      18204 non-null  float64
#  9   Preferred Foot            18198 non-null  object
#  10  International Reputation  18154 non-null  float64
#  11  Skill Moves               18156 non-null  float64
#  12  Position                  18205 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           3
# Nationality                   0
# Overall                      12
# Potential                     1
# Club                        241
# Value                       260
# Wage                          3
# Preferred Foot                9
# International Reputation     53
# Skill Moves                  51
# Position                      2
# Joined                        5
# Contract Valid Until        292
# Height                        2
# Weight                        5
# Release Clause                1
# dtype: int64

# %%
k1=df.Age.median()

# %%
k1
# Out:
# 25.0

# %%
df['Age']=df.Age.fillna(df.Age.median())

# %%
df.Age.isnull().sum()
# Out:
# 0

# %%
df['Overall']=df.Overall.fillna(df.Overall.median())

# %%
df.Overall.isnull().sum()
# Out:
# 0

# %%
df['Potential']=df.Potential.fillna(df.Potential.median())

# %%
df.Potential.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#            ID                Name   Age Nationality  Overall  Potential  \
# 0      158023            L. Messi  31.0   Argentina     94.0       94.0
# 1       20801   Cristiano Ronaldo  33.0    Portugal     94.0       94.0
# 2      190871           Neymar Jr  26.0      Brazil     92.0       93.0
# 3      193080              De Gea  27.0       Spain     91.0       93.0
# 4      192985        K. De Bruyne  27.0     Belgium     91.0       92.0
# ...       ...                 ...   ...         ...      ...        ...
# 18202  238813        J. Lundstram  19.0     England     47.0       65.0
# 18203  243165  N. Christoffersson  19.0      Sweden     47.0       63.0
# 18204  241638           B. Worman  16.0     England     47.0       67.0
# 18205  246268      D. Walker-Rice  17.0     England     47.0       66.0
# 18206  246269           G. Nugent  16.0     England     46.0       66.0
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       260
# Wage                          3
# Preferred Foot                9
# International Reputation     53
# Skill Moves                  51
# Position                      2
# Joined                        5
# Contract Valid Until        292
# Height                        2
# Weight                        5
# Release Clause                1
# dtype: int64

# %%
df.dropna(subset=['Club','Position','Preferred Foot','Contract Valid Until'],inplace=True)

# %%
df['Skill Moves']=df['Skill Moves'].fillna(df['Skill Moves'].mean())

# %%
df['Height']=df.Height.fillna(df.Height.median())
df['Weight']=df.Weight.fillna(df.Weight.median())
df['Joined']=df.Joined.fillna(df.Joined.median())
df['Value']=df.Value.fillna(df.Value.median())
df['Wage']=df.Wage.fillna(df.Wage.median())
df['International Reputation']=df['International Reputation'].fillna(df['International Reputation'].mean())
df['Skill Moves']=df['Skill Moves'].fillna(df['Skill Moves'].mean())
df['Release Clause']=df['Release Clause'].fillna(df['Release Clause'].median())

# %%
df.isnull().sum()
# Out:
# ID                          0
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %%
df
# Out:
#            ID                Name   Age Nationality  Overall  Potential  \
# 0      158023            L. Messi  31.0   Argentina     94.0       94.0
# 1       20801   Cristiano Ronaldo  33.0    Portugal     94.0       94.0
# 2      190871           Neymar Jr  26.0      Brazil     92.0       93.0
# 3      193080              De Gea  27.0       Spain     91.0       93.0
# 4      192985        K. De Bruyne  27.0     Belgium     91.0       92.0
# ...       ...                 ...   ...         ...      ...        ...
# 18202  238813        J. Lundstram  19.0     England     47.0       65.0
# 18203  243165  N. Christoffersson  19.0      Sweden     47.0       63.0
# 18204  241638           B. Worman  16.0     England     47.0       67.0
# 18205  246268      D. Walker-Rice  17.0     England     47.0       66.0
# 18206  246269           G. Nugent  16.0     England     46.0       66.0
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
a1=df.Age.max()

# %%
a1
# Out:
# 45.0

# %%
a2=df.Age.min()
a2
# Out:
# 16.0

# %%
#youngest and Oldest players
df.loc[((df.Age)==45)|((df.Age)==16)]
# Out:
#            ID             Name   Age          Nationality  Overall  Potential  \
# 4741   140029         O. Pérez  45.0               Mexico     71.0       71.0
# 11457  241266      W. Geubbels  16.0               France     64.0       86.0
# 11732  244403         A. Taoui  16.0               France     64.0       75.0
# 12496  245616   Pelayo Morilla  16.0                Spain     63.0       81.0
# 12828  246465         Guerrero  16.0                Spain     63.0       76.0
# 13293  246594      H. Massengo  16.0               France     62.0       75.0
# 13567  246419   Y. Verschaeren  16.0              Belgium     62.0       83.0
# 15363  245015        Y. Roemer  16.0          Netherlands     59.0       75.0
# 15746  243169      Y. Begraoui  16.0               France     59.0       81.0
# 15793  241650         J. Lahne  16.0               Sweden     59.0       77.0
# 16081  241552      J. Italiano  16.0            Australia     58.0       79.0
# ...

# %%
h=df.Value.max()
j=df.Value.min()
df.loc[((df.Value)==h)|((df.Value)==j)]
# Out:
#            ID              Name   Age   Nationality  Overall  Potential  \
# 2      190871         Neymar Jr  26.0        Brazil     92.0       93.0
# 14759  182312          Yang Jun  37.0      China PR     60.0       60.0
# 15133  104900         M. Gurski  39.0       Germany     60.0       60.0
# 15426   18745          M. Tyler  41.0       England     59.0       59.0
# 15508  120415        S. Shearer  37.0      Scotland     59.0       59.0
# 16204  176860        C. Månsson  37.0        Sweden     58.0       58.0
# 16249  176631       B. Lekström  37.0        Sweden     58.0       58.0
# 16264   28157   P. van der Vlag  40.0   Netherlands     58.0       58.0
# 16310   11800          C. Weale  36.0       England     57.0       57.0
# 16565  232893       K. Kitamoto  36.0         Japan     57.0       57.0
# 16596  219344      A. Al Basisi  40.0  Saudi Arabia     57.0       57.0
# 16628  102881  K. Stamatopoulos  38.0        Canada     57.0       57.0
# ...

# %%
#Top 10 players on the basis of value
sort=df.sort_values(by=['Value'],ascending=False)
tops=sort.head(10)

# %%
plt.plot(df.Weight,df.Weight,marker='*')
plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Weight vs Height")
# Out:
# Text(0.5, 1.0, 'Weight vs Height')

# %%
plt.barh(df.Weight,df.Potential)
plt.ylabel("Weight")
plt.xlabel("Potential")
plt.title("Weight vs Potential")
# Out:
# Text(0.5, 1.0, 'Weight vs Potential')

# %%
plt.barh(df.Age,df.Value)
plt.xlabel("Value")
plt.ylabel("Age")
plt.title("AGe vs Value")
# Out:
# Text(0.5, 1.0, 'AGe vs Value')

# %%
tops
# Out:
#         ID               Name   Age Nationality  Overall  Potential  \
# 2   190871          Neymar Jr  26.0      Brazil     92.0       93.0
# 0   158023           L. Messi  31.0   Argentina     94.0       94.0
# 4   192985       K. De Bruyne  27.0     Belgium     91.0       92.0
# 5   183277          E. Hazard  27.0     Belgium     91.0       91.0
# 15  211110          P. Dybala  24.0   Argentina     89.0       94.0
# 16  202126            H. Kane  24.0     England     89.0       91.0
# 25  231747          K. Mbappé  19.0      France     88.0       95.0
# 7   176580          L. Suárez  31.0     Uruguay     91.0       91.0
# 17  194765       A. Griezmann  27.0      France     89.0       90.0
# 1    20801  Cristiano Ronaldo  33.0    Portugal     94.0       94.0
#
#                    Club     Value   Wage Preferred Foot  \
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 0          FC Barcelona  110500.0  565.0           Left
# ...

# %%
plt.barh(tops.Name,tops['International Reputation'],)
plt.xlabel("Name of Players ")
plt.ylabel("International Reputation")
plt.title("Players vs Reputation")
# Out:
# Text(0.5, 1.0, 'Players vs Reputation')

# %%
right_foot=df[(df["Preferred Foot"]=='Right')]

# %%
tops_right=right_foot.sort_values(by=['Value'],ascending=False)
tops_right.head(10)
# Out:
#         ID               Name   Age Nationality  Overall  Potential  \
# 2   190871          Neymar Jr  26.0      Brazil     92.0       93.0
# 4   192985       K. De Bruyne  27.0     Belgium     91.0       92.0
# 5   183277          E. Hazard  27.0     Belgium     91.0       91.0
# 16  202126            H. Kane  24.0     England     89.0       91.0
# 25  231747          K. Mbappé  19.0      France     88.0       95.0
# 7   176580          L. Suárez  31.0     Uruguay     91.0       91.0
# 1    20801  Cristiano Ronaldo  33.0    Portugal     94.0       94.0
# 10  188545     R. Lewandowski  29.0      Poland     90.0       90.0
# 11  182521           T. Kroos  28.0     Germany     90.0       90.0
# 31  190460         C. Eriksen  26.0     Denmark     88.0       91.0
#
#                    Club     Value   Wage Preferred Foot  \
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 4       Manchester City  102000.0  355.0          Right
# ...

# %%
df["Year"]=pd.DatetimeIndex(df['Contract Valid Until']).year

# %%
new_df=df.drop(columns=['Contract Valid Until'])

# %%
new_df
# Out:
#            ID                Name   Age Nationality  Overall  Potential  \
# 0      158023            L. Messi  31.0   Argentina     94.0       94.0
# 1       20801   Cristiano Ronaldo  33.0    Portugal     94.0       94.0
# 2      190871           Neymar Jr  26.0      Brazil     92.0       93.0
# 3      193080              De Gea  27.0       Spain     91.0       93.0
# 4      192985        K. De Bruyne  27.0     Belgium     91.0       92.0
# ...       ...                 ...   ...         ...      ...        ...
# 18202  238813        J. Lundstram  19.0     England     47.0       65.0
# 18203  243165  N. Christoffersson  19.0      Sweden     47.0       63.0
# 18204  241638           B. Worman  16.0     England     47.0       67.0
# 18205  246268      D. Walker-Rice  17.0     England     47.0       66.0
# 18206  246269           G. Nugent  16.0     England     46.0       66.0
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
#top players with Contract expring this year with respect to value
new_df[(new_df.Year)==2022].sort_values(by=['Value'],ascending=False).head(10)
# Out:
#         ID               Name   Age Nationality  Overall  Potential  \
# 2   190871          Neymar Jr  26.0      Brazil     92.0       93.0
# 15  211110          P. Dybala  24.0   Argentina     89.0       94.0
# 25  231747          K. Mbappé  19.0      France     88.0       95.0
# 1    20801  Cristiano Ronaldo  33.0    Portugal     94.0       94.0
# 11  182521           T. Kroos  28.0     Germany     90.0       90.0
# 30  197781               Isco  26.0       Spain     88.0       91.0
# 47  192505          R. Lukaku  25.0     Belgium     66.0       89.0
# 29  198219         L. Insigne  27.0       Italy     88.0       88.0
# 36  173731            G. Bale  28.0       Wales     88.0       88.0
# 56  218667     Bernardo Silva  23.0    Portugal     86.0       91.0
#
#                    Club     Value   Wage Preferred Foot  \
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 15             Juventus   89000.0  205.0           Left
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17904 entries, 0 to 18206
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17904 non-null  int64
#  1   Name                      17904 non-null  object
#  2   Age                       17904 non-null  float64
#  3   Nationality               17904 non-null  object
#  4   Overall                   17904 non-null  float64
#  5   Potential                 17904 non-null  float64
#  6   Club                      17904 non-null  object
#  7   Value                     17904 non-null  float64
#  8   Wage                      17904 non-null  float64
#  9   Preferred Foot            17904 non-null  object
#  10  International Reputation  17904 non-null  float64
#  11  Skill Moves               17904 non-null  float64
#  12  Position                  17904 non-null  object
# ...

# %%
tops_c=new_df.Nationality.value_counts()

# %%
tops_country=pd.DataFrame(tops_c)

# %%
tops_country=tops_country.reset_index()

# %%
tops_country=tops_country.rename(columns={"index":"Country","Nationality":"Players"})

# %%
tops_country
# Out:
#                   Country  Players
# 0                 England     1657
# 1                 Germany     1194
# 2                   Spain     1068
# 3               Argentina      935
# 4                  France      910
# ..                    ...      ...
# 158                  Guam        1
# 159                Belize        1
# 160                 Malta        1
# 161  United Arab Emirates        1
# 162                 Qatar        1
#
# [163 rows x 2 columns]

# %%
plt.figure(figsize=(10,27))
plt.tight_layout(pad=0.5)
plt.barh(tops_country.Country,tops_country.Players)
plt.xlabel("Number of players")
plt.ylabel("Country")
plt.title("Number of players Vs Country")
# Out:
# Text(0.5, 1.0, 'Number of players Vs Country')

# %%
wage=new_df.sort_values(by=['Wage'],ascending=False).head(10)

# %%
sns.barplot(wage.Wage,wage.Name)
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Wage', ylabel='Name'>

# %%
foot_analy=new_df.sort_values(by=['Wage'],ascending=False).head(10)

# %%
plt.barh(foot_analy['Preferred Foot'],foot_analy['Skill Moves'])
plt.xlabel("Skills Moves")
plt.ylabel("Preffered Foot")
plt.title("Preffered foot vs Skills moves of Top 10 Players")
# Out:
# Text(0.5, 1.0, 'Preffered foot vs Skills moves of Top 10 Players')
