# %%
n=100000
prime=[]
for i in range(n+1):
    prime.append(i)
prime[0]=0
prime[1]=0
p=2
while p*p<=n:
    if p!=0:
        for i in range(p*p,n+1,p):
            prime[i]=0
    p=p+1
k=[]
for i in range(len(prime)):
    if prime[i]!=0:
        k.append(prime[i])
#print(k)

# %%
# Create a data frame containing a student database with atleast 10 students. The
# columns should be Name, gender, Marks(Maths, Science, Social, English, Computer)
# and perform following tasks
# 1. Create a new column with total of all the marks
# 2. Ranke the students based on the total in a new column
# 3. Filter top 3 students
# 4. Add a new student with a 100% score in all the subjects and do the ranking again

# %%
import pandas as pd
import numpy as np
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [50, 90,75, np.nan, 90, 65, 75, np.nan, 80, 90],
        'score2': [80, 90,85, np.nan, 70, 75, 80, np.nan, 65, 80],
        'Gender': ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F'],
        'Subjects': ['Science', 'Maths', 'Social Science', 'Computers', 'Python', 'Chemistry', 'Hindi', 'English', 'Java Scripst', 'Java'],
        'Subjects2':['Java','Java Scripst','English','Hindi','Chemistry','Python','Computers','Social Science','Maths','Science']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data , index=labels)
# print("\nMean score for each different student in data frame:")
#print(df['score'].mean())
df["Total Marks in both subjects"]=df.score+df.score2
df["Maximum Marks"]=200
df
# Out:
#         name  score  score2 Gender        Subjects       Subjects2  \
# a  Anastasia   50.0    80.0      M         Science            Java
# b       Dima   90.0    90.0      F           Maths    Java Scripst
# c  Katherine   75.0    85.0      M  Social Science         English
# d      James    NaN     NaN      F       Computers           Hindi
# e      Emily   90.0    70.0      M          Python       Chemistry
# f    Michael   65.0    75.0      F       Chemistry          Python
# g    Matthew   75.0    80.0      M           Hindi       Computers
# h      Laura    NaN     NaN      F         English  Social Science
# i      Kevin   80.0    65.0      M    Java Scripst           Maths
# j      Jonas   90.0    80.0      F            Java         Science
#
#    Total Marks in both subjects  Maximum Marks
# a                         130.0            200
# b                         180.0            200
# c                         160.0            200
# ...

# %%
# # 2. Ranke the students based on the total in a new column
# # 3. Filter top 3 students
# # 4. Add a new student with a 100% score in all the subjects and do the ranking again

df
# Out:
#         name  score  score2 Gender        Subjects       Subjects2  \
# a  Anastasia   50.0    80.0      M         Science            Java
# b       Dima   90.0    90.0      F           Maths    Java Scripst
# c  Katherine   75.0    85.0      M  Social Science         English
# d      James    NaN     NaN      F       Computers           Hindi
# e      Emily   90.0    70.0      M          Python       Chemistry
# f    Michael   65.0    75.0      F       Chemistry          Python
# g    Matthew   75.0    80.0      M           Hindi       Computers
# h      Laura    NaN     NaN      F         English  Social Science
# i      Kevin   80.0    65.0      M    Java Scripst           Maths
# j      Jonas   90.0    80.0      F            Java         Science
#
#    Total Marks in both subjects  Maximum Marks
# a                         130.0            200
# b                         180.0            200
# c                         160.0            200
# ...

# %%
df["score"]=df["score"].fillna(df["score"].median())
df["score2"]=df["score2"].fillna(df["score2"].median())
df["Total Marks in both subjects"]=df["Total Marks in both subjects"].fillna(df["Total Marks in both subjects"].median())

# %%
df.sort_values(by=["Total Marks in both subjects"],ascending=False,inplace=True)

# %%
df
# Out:
#         name  score  score2 Gender        Subjects       Subjects2  \
# b       Dima   90.0    90.0      F           Maths    Java Scripst
# j      Jonas   90.0    80.0      F            Java         Science
# c  Katherine   75.0    85.0      M  Social Science         English
# e      Emily   90.0    70.0      M          Python       Chemistry
# d      James   77.5    80.0      F       Computers           Hindi
# h      Laura   77.5    80.0      F         English  Social Science
# g    Matthew   75.0    80.0      M           Hindi       Computers
# i      Kevin   80.0    65.0      M    Java Scripst           Maths
# f    Michael   65.0    75.0      F       Chemistry          Python
# a  Anastasia   50.0    80.0      M         Science            Java
#
#    Total Marks in both subjects  Maximum Marks
# b                         180.0            200
# j                         170.0            200
# c                         160.0            200
# ...

# %%
df["Percenatge"]=df["Total Marks in both subjects"]*100/df["Maximum Marks"]

# %%
df
# Out:
#         name  score  score2 Gender        Subjects       Subjects2  \
# b       Dima   90.0    90.0      F           Maths    Java Scripst
# j      Jonas   90.0    80.0      F            Java         Science
# c  Katherine   75.0    85.0      M  Social Science         English
# e      Emily   90.0    70.0      M          Python       Chemistry
# d      James   77.5    80.0      F       Computers           Hindi
# h      Laura   77.5    80.0      F         English  Social Science
# g    Matthew   75.0    80.0      M           Hindi       Computers
# i      Kevin   80.0    65.0      M    Java Scripst           Maths
# f    Michael   65.0    75.0      F       Chemistry          Python
# a  Anastasia   50.0    80.0      M         Science            Java
#
#    Total Marks in both subjects  Maximum Marks  Percenatge
# b                         180.0            200       90.00
# j                         170.0            200       85.00
# ...

# %%
df['rank'] = df['Total Marks in both subjects'].rank(ascending=False)

# %%
new=[]
for i in df['rank']:
    new.append(math.floor(i))
# Out:
# [1, 2, 3, 3, 5, 5, 7, 8, 9, 10]

# %%
df['rank']=new

# %%
df
# Out:
#         name  score  score2 Gender        Subjects       Subjects2  \
# b       Dima   90.0    90.0      F           Maths    Java Scripst
# j      Jonas   90.0    80.0      F            Java         Science
# c  Katherine   75.0    85.0      M  Social Science         English
# e      Emily   90.0    70.0      M          Python       Chemistry
# d      James   77.5    80.0      F       Computers           Hindi
# h      Laura   77.5    80.0      F         English  Social Science
# g    Matthew   75.0    80.0      M           Hindi       Computers
# i      Kevin   80.0    65.0      M    Java Scripst           Maths
# f    Michael   65.0    75.0      F       Chemistry          Python
# a  Anastasia   50.0    80.0      M         Science            Java
#
#    Total Marks in both subjects  Maximum Marks  Percenatge  rank
# b                         180.0            200       90.00     1
# j                         170.0            200       85.00     2
# ...

# %%
#top 3 students 
df.head(3)
# Out:
#         name  score  score2 Gender        Subjects     Subjects2  \
# b       Dima   90.0    90.0      F           Maths  Java Scripst
# j      Jonas   90.0    80.0      F            Java       Science
# c  Katherine   75.0    85.0      M  Social Science       English
#
#    Total Marks in both subjects  Maximum Marks  Percenatge  rank
# b                         180.0            200        90.0     1
# j                         170.0            200        85.0     2
# c                         160.0            200        80.0     3
